# %%
import os
import glob
from asp_plot.utils import show_existing_figure

# %%
directory = "/Users/ben/Dropbox/UW_Shean/WV/2022/WV03_20220417_1040010074793300_1040010075633C00/"

plots_directory = os.path.join(directory, "stereo_report_plots")
os.makedirs(plots_directory, exist_ok=True)

# %%
try:
    filename = glob.glob(os.path.join(plots_directory, "00_stereo_geom.png"))[0]
except:
    # !dg_geom_plot.py $directory/
    # !mv $directory/*stereo_geom.png $plots_directory/00_stereo_geom.png
    filename = glob.glob(os.path.join(plots_directory, "00_stereo_geom.png"))[0]

show_existing_figure(filename)
# Out:
# Extracting pair dictionary from xml within directory
# {'id1_dict': {'id': '1040010074793300', 'sensor': 'WV03', 'date': datetime.datetime(2022, 4, 17, 22, 51, 49, 53175), 'alt': -99999.0, 'az': 350.5, 'el': 67.4, 'sunaz': 187.3, 'sunel': 29.4, 'gsd': 0.35, 'scandir': 'Forward', 'tdi': 32, 'offnadir': 20.6, 'intrack': 15.9, 'crosstrack': -13.3, 'cloudcover': 0.0, 'geom': <osgeo.ogr.Geometry; proxy of <Swig Object of type 'OGRGeometryShadow *' at 0x13bb374b0> >, 'geom_poly': <POLYGON ((-156.424 71.392, -156.425 71.268, -156.825 71.272, -156.826 71.39...>, 'stereopair': None}, 'id2_dict': {'id': '1040010075633C00', 'sensor': 'WV03', 'date': datetime.datetime(2022, 4, 17, 22, 52, 47, 937775), 'alt': -99999.0, 'az': 244.3, 'el': 63.9, 'sunaz': 187.6, 'sunel': 29.4, 'gsd': 0.36, 'scandir': 'Forward', 'tdi': 32, 'offnadir': 23.5, 'intrack': -19.1, 'crosstrack': -14.0, 'cloudcover': 0.0, 'geom': <osgeo.ogr.Geometry; proxy of <Swig Object of type 'OGRGeometryShadow *' at 0x13d46e580> >, 'geom_poly': <POLYGON ((-156.4 71.401, -156.4 71.275, -156.847 71.264, -156.846 71.39, -1...>, 'stereopair': None}, 'intersection': <osgeo.ogr.Geometry; proxy of <Swig Object of type 'OGRGeometryShadow *' at 0x13d401aa0> >, 'intersection_poly': <POLYGON ((-156.425 71.274, -156.615 71.27, -156.825 71.272, -156.825 71.39,...>, 'int_w': 13.91, 'int_h': 14.33, 'intersection_area': 194.13, 'intersection_area_perc': (97.95, 86.48), 'pairtype': 'coincident', 'cdate': datetime.datetime(2022, 4, 17, 22, 52, 18, 495475), 'pairname': 'WV03_20220417_1040010074793300_1040010075633C00', 'dt': datetime.timedelta(seconds=58, microseconds=884600), 'conv_ang': 38.57, 'bh_ratio': 0.7}
# Creating figure
# Saving figure
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
# swig/python detected a memory leak of type 'OSRSpatialReferenceShadow *', no destructor found.
