# %%
import os
import glob
from asp_plot.utils import show_existing_figure

# %%
directory = "/Users/ben/Dropbox/UW_Shean/WV/2022/WV02_20220419_10300100D0772D00_10300100D12D7400/"

# %%
filename = glob.glob(os.path.join(directory, "*stereo_geom.png"))[0]

if not os.path.exists(filename):
    # !dg_geom_plot.py $directory

show_existing_figure(filename)
