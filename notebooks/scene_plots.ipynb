# %%
import os
import glob
from asp_plot.scenes import ScenePlotter

# %%
directory = "/Users/ben/Dropbox/UW_Shean/WV/2022/WV02_20220419_10300100D0772D00_10300100D12D7400/"

stereo_directory = "stereo*/"

# %%
left_ortho_fn
# Out:
# '/Users/ben/Dropbox/UW_Shean/WV/2022/WV02_20220419_10300100D0772D00_10300100D12D7400/stereo_ba_50ips_10matches_dg_weight_image__ortho_0.55m_mode_asp_mgm_spm_9_corr_7_rfne_15_cost_4_refdem_COP30/20220419_2321_10300100D12D7400_10300100D0772D00-L_sub.tif'

# %%
left_ortho_fn = glob.glob(os.path.join(directory, stereo_directory, '*-L_sub.tif'))[0]
right_ortho_fn = glob.glob(os.path.join(directory, stereo_directory, '*-R_sub.tif'))[0]

ScenePlotter(left_ortho_fn, right_ortho_fn).plot_orthos(title="Orthos")
