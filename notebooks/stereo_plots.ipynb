# %%
from asp_plot.stereo import StereoPlotter

# %%
directory = "/Users/ben/Dropbox/UW_Shean/WV/2022/WV02_20220419_10300100D0772D00_10300100D12D7400/"
stereo_directory = "stereo_ba_50ips_10matches_dg_weight_image__ortho_0.55m_mode_asp_mgm_spm_9_corr_7_rfne_15_cost_4_refdem_COP30/"
reference_dem = "/Users/ben/Dropbox/UW_Shean/COP/COP30_utqiagvik_lzw-adj_proj.tif"

# %%
plotter = StereoPlotter(
  directory, 
  stereo_directory,
  reference_dem,
  out_dem_gsd=1,
  add_cbar=False,
  title="Stereo Match Points"
  )

plotter.plot_match_points()

# %%
plotter = StereoPlotter(
  directory, 
  stereo_directory,
  reference_dem,
  out_dem_gsd=1,
  title="Disparity",
)

plotter.plot_disparity(unit="pixels") # Unit can be "meters" or "pixels"
