# %%
# %load_ext autoreload
# %autoreload 2

from asp_plot.scenes import ScenePlotter, SceneGeometryPlotter

# %%
# directory = "/Users/ben/Dropbox/UW_Shean/WV/antarctica/tiled_xmls_example/testing/"
directory = "/Users/ben/Dropbox/UW_Shean/WV/antarctica/tiled_xmls_example/WV01_20210201_10200100A1865800_10200100A37C1C00"
# directory = "/Users/ben/Dropbox/UW_Shean/WV/2022/WV03_20220417_1040010074793300_1040010075633C00/"

# %%
geometry_plotter = SceneGeometryPlotter(
  directory
)

geometry_plotter.dg_geom_plot()
# Out:
# More than two XML files found in directory. Mosaicing before proceeding.
#
#
# ...
